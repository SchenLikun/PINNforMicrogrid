# %%
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt

# %%
fnamevar = "PI_variables_ModelSave_0301_333.dat"
lines = open(fnamevar, "r").readlines()
# read output data in fnamevar (this line is a long story...)
Chat = np.array(
    [
        np.fromstring(
            min(re.findall(re.escape("[") + "(.*?)" + re.escape("]"), line), key=len),
            sep=",",
        )
        for line in lines
    ]
)
l, c = Chat.shape
plt.plot(range(l), Chat[:, 0], "r-")
plt.plot(range(l), Chat[:, 1], "b-")
plt.plot(range(l), Chat[:, 2], "g-")
plt.plot(range(l), Chat[:, 3], "y-")
plt.plot(range(l), np.ones(Chat[:, 0].shape) * 0.025, "r--")
plt.plot(range(l), np.ones(Chat[:, 0].shape) * 0.5, "r--")
plt.plot(range(l), np.ones(Chat[:, 0].shape) * 5., "r--")

plt.legend(["Kp1","Ki1", "Kp2","Ki2"], loc="right")
plt.xlabel("Epoch")
Chat[-10:-1]
# Out:
# array([[0.993 , 1.75  , 0.0283, 0.361 ],
#        [0.993 , 1.75  , 0.0283, 0.361 ],
#        [0.993 , 1.75  , 0.0283, 0.361 ],
#        [0.993 , 1.75  , 0.0283, 0.361 ],
#        [0.993 , 1.75  , 0.0283, 0.361 ],
#        [0.993 , 1.75  , 0.0283, 0.361 ],
#        [0.993 , 1.75  , 0.0283, 0.361 ],
#        [0.993 , 1.75  , 0.0283, 0.361 ],
#        [0.993 , 1.75  , 0.0283, 0.361 ]])

# %%
fnamevar = "PI_variables_ModelSave_0301.dat"
lines = open(fnamevar, "r").readlines()
# read output data in fnamevar (this line is a long story...)
Chat = np.array(
    [
        np.fromstring(
            min(re.findall(re.escape("[") + "(.*?)" + re.escape("]"), line), key=len),
            sep=",",
        )
        for line in lines
    ]
)
l, c = Chat.shape
plt.plot(range(l), Chat[:, 0], "r-")
plt.plot(range(l), Chat[:, 1], "b-")
plt.plot(range(l), Chat[:, 2], "g-")
plt.plot(range(l), Chat[:, 3], "y-")
plt.plot(range(l), np.ones(Chat[:, 0].shape) * 0.025, "r--")
plt.plot(range(l), np.ones(Chat[:, 0].shape) * 0.5, "r--")
plt.plot(range(l), np.ones(Chat[:, 0].shape) * 5., "r--")

plt.legend(["Kp1","Ki1", "Kp2","Ki2"], loc="right")
plt.xlabel("Epoch")
Chat[-10:-1]
# Out:
# array([[0.987 , 1.75  , 0.0285, 0.358 ],
#        [0.988 , 1.75  , 0.0285, 0.358 ],
#        [0.989 , 1.75  , 0.0285, 0.358 ],
#        [0.989 , 1.75  , 0.0284, 0.359 ],
#        [0.99  , 1.75  , 0.0284, 0.359 ],
#        [0.991 , 1.75  , 0.0284, 0.359 ],
#        [0.991 , 1.75  , 0.0284, 0.36  ],
#        [0.992 , 1.75  , 0.0284, 0.36  ],
#        [0.992 , 1.75  , 0.0284, 0.361 ]])
