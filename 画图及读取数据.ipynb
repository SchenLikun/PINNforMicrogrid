# %%
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt

# %%
fnamevar = "PI_variables_tanh_transall_0224.dat"
lines = open(fnamevar, "r").readlines()
# read output data in fnamevar (this line is a long story...)
Chat = np.array(
    [
        np.fromstring(
            min(re.findall(re.escape("[") + "(.*?)" + re.escape("]"), line), key=len),
            sep=",",
        )
        for line in lines
    ]
)
l, c = Chat.shape
plt.plot(range(l), Chat[:, 0], "r-")
plt.plot(range(l), Chat[:, 1], "b-")
plt.plot(range(l), Chat[:, 2], "g-")
plt.plot(range(l), Chat[:, 3], "y-")
plt.plot(range(l), np.ones(Chat[:, 0].shape) * 0.025, "r--")
plt.plot(range(l), np.ones(Chat[:, 0].shape) * 0.5, "r--")
plt.plot(range(l), np.ones(Chat[:, 0].shape) * 5., "r--")

plt.legend(["Kp1","Ki1", "Kp2","Ki2"], loc="right")
plt.xlabel("Epoch")
Chat[-10:-1]
# Out:
# array([[0.0285, 4.66  , 0.0251, 0.496 ],
#        [0.0285, 4.66  , 0.0251, 0.496 ],
#        [0.0285, 4.66  , 0.0251, 0.496 ],
#        [0.0285, 4.66  , 0.0251, 0.496 ],
#        [0.0285, 4.66  , 0.0251, 0.496 ],
#        [0.0285, 4.66  , 0.0251, 0.496 ],
#        [0.0285, 4.66  , 0.0251, 0.496 ],
#        [0.0285, 4.66  , 0.0251, 0.496 ],
#        [0.0284, 4.66  , 0.0251, 0.496 ]])

# %%
fnamevar = "PI_variables_swish_transtanh_ObAll_0226.dat"
lines = open(fnamevar, "r").readlines()
# read output data in fnamevar (this line is a long story...)
Chat = np.array(
    [
        np.fromstring(
            min(re.findall(re.escape("[") + "(.*?)" + re.escape("]"), line), key=len),
            sep=",",
        )
        for line in lines
    ]
)
l, c = Chat.shape
plt.plot(range(l), Chat[:, 0], "r-")
plt.plot(range(l), Chat[:, 1], "b-")
plt.plot(range(l), Chat[:, 2], "g-")
plt.plot(range(l), Chat[:, 3], "y-")
plt.plot(range(l), np.ones(Chat[:, 0].shape) * 0.025, "r--")
plt.plot(range(l), np.ones(Chat[:, 0].shape) * 0.5, "r--")
plt.plot(range(l), np.ones(Chat[:, 0].shape) * 5., "r--")

plt.legend(["Kp1","Ki1", "Kp2","Ki2"], loc="right")
plt.xlabel("Epoch")
Chat[-10:-1]
# Out:
# array([[0.03  , 4.79  , 0.0253, 0.493 ],
#        [0.03  , 4.79  , 0.0253, 0.493 ],
#        [0.03  , 4.79  , 0.0253, 0.493 ],
#        [0.0301, 4.79  , 0.0252, 0.493 ],
#        [0.03  , 4.79  , 0.0252, 0.494 ],
#        [0.03  , 4.79  , 0.0252, 0.493 ],
#        [0.0301, 4.79  , 0.0252, 0.493 ],
#        [0.03  , 4.79  , 0.0253, 0.494 ],
#        [0.0299, 4.79  , 0.0253, 0.494 ]])

# %%
fnamevar = "PI_variables_swish_transall_ObAll_0226.dat"
lines = open(fnamevar, "r").readlines()
# read output data in fnamevar (this line is a long story...)
Chat = np.array(
    [
        np.fromstring(
            min(re.findall(re.escape("[") + "(.*?)" + re.escape("]"), line), key=len),
            sep=",",
        )
        for line in lines
    ]
)
l, c = Chat.shape
plt.plot(range(l), Chat[:, 0], "r-")
plt.plot(range(l), Chat[:, 1], "b-")

plt.plot(range(l), np.ones(Chat[:, 0].shape) * 1.5, "r--")
plt.plot(range(l), np.ones(Chat[:, 0].shape) * 0.15, "r--")


plt.legend(["H","D"], loc="right")
plt.xlabel("Epoch")
Chat[-10:-1]
# Out:
# array([[0.0281, 4.87  , 0.0252, 0.494 ],
#        [0.0281, 4.87  , 0.0252, 0.494 ],
#        [0.0281, 4.87  , 0.0252, 0.494 ],
#        [0.0281, 4.87  , 0.0252, 0.494 ],
#        [0.0281, 4.87  , 0.0252, 0.494 ],
#        [0.0281, 4.87  , 0.0252, 0.494 ],
#        [0.0281, 4.87  , 0.0252, 0.494 ],
#        [0.0281, 4.87  , 0.0252, 0.494 ],
#        [0.0282, 4.87  , 0.0252, 0.494 ]])

# %%
fnamevar = "SYNC_variables_0315_TransNone.dat"
lines = open(fnamevar, "r").readlines()
# read output data in fnamevar (this line is a long story...)
Chat = np.array(
    [
        np.fromstring(
            min(re.findall(re.escape("[") + "(.*?)" + re.escape("]"), line), key=len),
            sep=",",
        )
        for line in lines
    ]
)
l, c = Chat.shape
plt.plot(range(l), Chat[:, 0], "r-")
plt.plot(range(l), Chat[:, 1], "b-")

plt.plot(range(l), np.ones(Chat[:, 0].shape) * 1.5, "r--")
plt.plot(range(l), np.ones(Chat[:, 0].shape) * 0.15, "r--")


plt.legend(["H","D"], loc="right")
plt.xlabel("Epoch")
Chat[-10:-1]
# Out:
# array([[ 1.5 , -1.02],
#        [ 1.5 , -1.02],
#        [ 1.5 , -1.02],
#        [ 1.5 , -1.02],
#        [ 1.5 , -1.03],
#        [ 1.5 , -1.03],
#        [ 1.5 , -1.03],
#        [ 1.5 , -1.03],
#        [ 1.5 , -1.03]])
