# %%
import pandas as pd
import os
import re
import numpy as np
import matplotlib.pyplot as plt

# %%
date = '1208'
variable = ['H', 'D']

# %%
file_list = os.listdir('data')
file_list = [f for f in file_list if date in f]

# %%
class Data():
    def __init__(self):
        pass

# %%
data_dict = {}

# %%
for f in file_list:
    f_info = f.replace('.csv', '').split('_')
    locals()[f_info[1]] = Data()
    locals()[f_info[1]].date = f_info[0]
    locals()[f_info[1]].case = f_info[1]
    locals()[f_info[1]].variables = re.findall(r'[0-9]+\.?[0-9]*',f_info[2])
    locals()[f_info[1]].data = pd.read_csv('data/'+f)
    data_dict[f_info[1]+f_info[2]] = locals()[f_info[1]]

# %%
data_dict
# Out:
# {'LdChangeH1.0D0.0': <__main__.Data at 0x1b665023c10>,
#  'LdChangeH1.2D0.12': <__main__.Data at 0x1b665023bd0>,
#  'LdChangeH1.5D0.2': <__main__.Data at 0x1b664fb8a50>,
#  'LdChangeH1.5D0.25': <__main__.Data at 0x1b664b7b450>,
#  'LdChangeH1.8D0.2': <__main__.Data at 0x1b66501ed90>,
#  'SyncOnH1.0D0.0': <__main__.Data at 0x1b66501f550>,
#  'SyncOnH1.2D0.12': <__main__.Data at 0x1b66501fdd0>,
#  'SyncOnH1.5D0.1': <__main__.Data at 0x1b66501ef90>,
#  'SyncOnH1.5D0.2': <__main__.Data at 0x1b66502cd10>,
#  'SyncOnH1.5D0.25': <__main__.Data at 0x1b66502d010>,
#  'SyncOnH1.8D0.2': <__main__.Data at 0x1b66502d290>}

# %%
for v in data_dict.values():
    print(v.case)
    print(v.variables)
    pd_data = v.data
    pd_data.columns = ['Time', 'Tm', 'w_pu', 'Te', 'w_sync']
    time_step = pd_data.Time[1] - pd_data.Time[0]
    w_pu_t = (pd_data.w_pu.to_numpy()[2:] - pd_data.w_pu.to_numpy()[:-2]) / (2 * time_step)
    w_sync_t = (pd_data.w_sync.to_numpy()[2:] - pd_data.w_sync.to_numpy()[:-2]) / (2 * time_step)
    result_w_pu = pd_data.Tm.to_numpy()[1:-1] - pd_data.Te.to_numpy()[1:-1] - 2*np.float64(v.variables[0])*w_pu_t - np.float64(v.variables[1])*(pd_data.w_pu.to_numpy()[1:-1]-1)
    result_w_sync = pd_data.Tm.to_numpy()[1:-1] - pd_data.Te.to_numpy()[1:-1] - 2*np.float64(v.variables[0])*w_sync_t - np.float64(v.variables[1])*(pd_data.w_sync.to_numpy()[1:-1]-1)

    plt.figure()
    plt.plot(result_w_pu, label = 'w_pu')
    plt.plot(result_w_sync, label = 'w_sync')
#     plt.plot(result_w_pu+result_w_sync, label = 'add')
    plt.legend()
    plt.show()
    plt.figure()
    plt.plot(result_w_pu, label = 'w_pu')
    plt.plot(result_w_sync, label = 'w_sync')
    plt.plot(result_w_pu+result_w_sync, label = 'add')
    plt.legend()
    plt.show()
# Out:
# LdChange
# ['1.0', '0.0']
# LdChange
# ['1.2', '0.12']
# LdChange
# ['1.5', '0.2']
# LdChange
# ['1.5', '0.25']
# LdChange
# ['1.8', '0.2']
# SyncOn
# ['1.0', '0.0']
# SyncOn
# ['1.2', '0.12']
# SyncOn
# ['1.5', '0.1']
# SyncOn
# ['1.5', '0.2']
# SyncOn
# ['1.5', '0.25']
# SyncOn
# ['1.8', '0.2']
