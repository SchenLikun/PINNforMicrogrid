# %%
import pandas as pd
# import deepxde as dde
import numpy as np
import re
import matplotlib.pyplot as plt

# %%
fnamevar = "./history_data/ParaEs_Synchronous/2-order for H AND D/3variables_31012.dat"
lines = open(fnamevar, "r").readlines()
# read output data in fnamevar (this line is a long story...)
Chat = np.array(
    [
        np.fromstring(
            min(re.findall(re.escape("[") + "(.*?)" + re.escape("]"), line), key=len),
            sep=",",
        )
        for line in lines
    ]
)

# %%
l, c = Chat.shape
plt.plot(range(l), Chat[:, 0], "r-")
plt.plot(range(l), Chat[:, 1], "b-")
plt.plot(range(l), np.ones(Chat[:, 0].shape) * 1.5, "r--")
plt.plot(range(l), np.ones(Chat[:, 0].shape) * 0.15, "b--")

plt.legend(["Hhat","D"], loc="right")
plt.xlabel("Epoch")
Chat[-10:-1]
# Out:
# array([[1.5  , 0.176],
#        [1.5  , 0.176],
#        [1.5  , 0.176],
#        [1.5  , 0.177],
#        [1.5  , 0.177],
#        [1.5  , 0.177],
#        [1.5  , 0.177],
#        [1.5  , 0.177],
#        [1.5  , 0.177]])

# %%
Chat[-10:-1]
# Out:
# array([[7.48, 1.  ],
#        [7.48, 1.  ],
#        [7.48, 1.  ],
#        [7.48, 1.  ],
#        [7.48, 1.  ],
#        [7.48, 1.  ],
#        [7.48, 1.  ],
#        [7.48, 1.  ],
#        [7.48, 1.  ]])

# %%
fnamevar2 = "variables7_1213_PID_base.dat"

# %%
lines2 = open(fnamevar2, "r").readlines()
# read output data in fnamevar (this line is a long story...)
Chat2 = np.array(
    [
        np.fromstring(
            min(re.findall(re.escape("[") + "(.*?)" + re.escape("]"), line), key=len),
            sep=",",
        )
        for line in lines2
    ]
)

# %%
l2, c2 = Chat2.shape
plt.plot(range(l2), Chat2[:, 0], "r-")
plt.plot(range(l2), Chat2[:, 1], "b-")
plt.plot(range(l2), np.ones(Chat2[:, 0].shape) * 1.5, "r--")

plt.legend(["Hhat","True H"], loc="right")
plt.xlabel("Epoch")
# Out:
# Text(0.5, 0, 'Epoch')

# %%
Chat2
# Out:
# array([[1.  , 1.  ],
#        [1.01, 1.  ],
#        [1.  , 1.  ],
#        ...,
#        [9.01, 1.  ],
#        [9.01, 1.  ],
#        [9.01, 1.  ]])

# %%
fnamevar = "variables6_21214_PID_base.dat"
lines = open(fnamevar, "r").readlines()
# read output data in fnamevar (this line is a long story...)
Chat = np.array(
    [
        np.fromstring(
            min(re.findall(re.escape("[") + "(.*?)" + re.escape("]"), line), key=len),
            sep=",",
        )
        for line in lines
    ]
)
l, c = Chat.shape
plt.plot(range(l), Chat[:, 0], "r-")
plt.plot(range(l), Chat[:, 1], "b-")
plt.plot(range(l), np.ones(Chat[:, 0].shape) * 1.5, "r--")

plt.legend(["Hhat","True H"], loc="right")
plt.xlabel("Epoch")
# Out:
# Text(0.5, 0, 'Epoch')

# %%
fnamevar = "variables7_21214_PID_base.dat"
lines = open(fnamevar, "r").readlines()
# read output data in fnamevar (this line is a long story...)
Chat = np.array(
    [
        np.fromstring(
            min(re.findall(re.escape("[") + "(.*?)" + re.escape("]"), line), key=len),
            sep=",",
        )
        for line in lines
    ]
)
l, c = Chat.shape
plt.plot(range(l), Chat[:, 0], "r-")
plt.plot(range(l), Chat[:, 1], "b-")
plt.plot(range(l), np.ones(Chat[:, 0].shape) * 1.5, "r--")

plt.legend(["Hhat","True H"], loc="right")
plt.xlabel("Epoch")
# Out:
# Text(0.5, 0, 'Epoch')
